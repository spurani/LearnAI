# %%
import pandas as pd
data = pd.read_csv('Datasets/Claim_Dataset_Part1.csv')
# Out:
#        UID     PhID   PresID          CLID   PATID        ID         DCID  \
# 0        1  3127172  2031955  1.820000e+14  200599  77687332    406048533
# 1        2  3127934  3145680  1.820000e+14  200810  76558228  65162003434
# 2        3  3127934  3146402  1.820000e+14  200810  77705008  62037052524
# 3        4  3127934  3147500  1.820000e+14  200810  77705143  65162003434
# 4        5  3141427  1041174  1.700000e+14  201658  59837307  42858010324
# 5        6  3141427  1048223  1.710000e+14  201658  61959467  42858010324
# 6        7  3141427  1060706  1.710000e+14  201658  64131700  42858010324
# 7        8  3139050   887894  1.700000e+14  201666  59760195    603388844
# 8        9  3194529   888298  1.710000e+14  201666  62265118    603389244
# 9       10  3199300   294862  1.720000e+14  201781  65688552  42858020473
# 10      11  3139114  1760464  1.740000e+14  202002  71443383  13107006122
# 11      12  3193080  2252348  1.740000e+14  202743  71768022    406012524
# ...
