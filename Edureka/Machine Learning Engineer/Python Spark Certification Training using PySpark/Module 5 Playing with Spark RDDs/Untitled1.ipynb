# %%
import pyspark
from pyspark import SparkContext
sc = SparkContext()
from pyspark.sql import SQLContext, Row
sqlContext = SQLContext(sc)
from pyspark.sql import SparkSession, functions
spark = SparkSession.builder.appName('abc').getOrCreate()

# %%
lines = sc.textFile("651_m5_cs2_datasets_v1.0/access.log")
parts = lines.map(lambda l: l.split(" "))
#lines.collect()
#parts.collect()
re_code = parts.map(lambda d: d[8])
re_code.collect()
save_re = re_code
save_re.map(lambda row: str(row[0]) + "\t" + str(row[1])) \
   .saveAsTextFile("res")  # good format
#for a in re_code.collect():
#    print(a)
#res_code = parts.map(lambda d: Row(data_detail=d[8]))
#schema_res_code = spark.createDataFrame(res_code)
#schema_res_code.createOrReplaceTempView("logs")
#sqlquery = spark.sql("SELECT count(data_detail) from logs where data_detail like '%404%' ").show()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-94-7a9faaf3c7b2> in <module>
#       7 save_re = re_code
#       8 save_re.map(lambda row: str(row[0]) + "\t" + str(row[1])) \
# ----> 9    .saveAsTextFile("res_tsv.txt")  # good format
#      10 #for a in re_code.collect():
#      11 #    print(a)
#
# ~\Anaconda3\lib\site-packages\pyspark\rdd.py in saveAsTextFile(self, path, compressionCodecClass)
#    1654             keyed._jrdd.map(self.ctx._jvm.BytesToString()).saveAsTextFile(path, compressionCodec)
#    1655         else:
# -> 1656             keyed._jrdd.map(self.ctx._jvm.BytesToString()).saveAsTextFile(path)
#    1657
#    1658     # Pair functions
#
# ~\Anaconda3\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
# ...

# %%
parts.collect()
# Out:
# [['109.169.248.247',
#   '-',
#   '-',
#   '[12-Dec-2015:18:25:11',
#   '+0100]',
#   'GET',
#   '/administrator/',
#   'HTTP/1.1',
#   '200',
#   '4263',
#   '-',
#   'Mozilla/5.0',
#   '(Windows',
#   'NT',
#   '6.0;',
#   'rv:34.0)',
#   'Gecko/20100101',
#   'Firefox/34.0',
#   '-'],
#  ['109.169.248.247',
#   '-',
#   '-',
#   '[12/Dec/2015:18:25:11',
#   '+0100]',
#   'POST',
#   '/administrator/index.php',
#   'HTTP/1.1',
#   '200',
#   '4494',
#   'http://almhuette-raith.at/administrator/',
#   'Mozilla/5.0',
#   '(Windows',
#   'NT',
#   '6.0;',
#   'rv:34.0)',
#   'Gecko/20100101',
#   'Firefox/34.0',
#   '-'],
#  ['46.72.177.4',
#   '-',
#   '-',
#   '[12/Dec/2015:18:31:08',
#   '+0100]',
#   'GET',
#   '/administrator/',
#   'HTTP/1.1',
#   '404',
#   '4263',
#   'http://almhuette-raith.at/administrator/',
#   'Mozilla/5.0',
#   '(Windows',
#   'NT',
#   '6.0;',
#   'rv:34.0)',
#   'Gecko/20100101',
#   'Firefox/34.0',
#   '-'],
#  ['46.72.177.4',
#   '-',
#   '-',
# ...

# %%
broken_url = parts.map(lambda d: Row(url=d[10],code=d[8]))
broken_url.collect()
schema_broken_url = spark.createDataFrame(broken_url)
schema_broken_url.createOrReplaceTempView("logs")
sqlquery = spark.sql("SELECT url from logs where code like '404' ").show()
# Out:
# +--------------------+
# |                 url|
# +--------------------+
# |http://almhuette-...|
# |http://almhuette-...|
# |                   -|
# |http://almhuette-...|
# |                   -|
# |                   -|
# +--------------------+

# %%
parts = lines.map(lambda l: l.split("["))
col = parts.collect()
checker = []
for a in col:
       checker.append(a[1].split("]"))
#print(checker)
for b in checker:
        print(b[0].split(":"))
#http_status_with_count = parts.map(lambda l: l.split("]"))
#http_status_with_count.collect()
#http_status_with_parts = parts.map(lambda d: Row(date_time=d[1]))
#http_status_with_count.collect()
#schema_http_status_count = spark.createDataFrame(http_status_with_count)
#schema_http_status_count.createOrReplaceTempView("logs")
#sqlquery = spark.sql("SELECT date_time from logs").show()
# Out:
# ['12-Dec-2015', '18', '25', '11 +0100']
# ['12/Dec/2015', '18', '25', '11 +0100']
# ['12/Dec/2015', '18', '31', '08 +0100']
# ['12/Dec/2015', '18', '31', '08 +0100']
# ['12/Dec/2015', '18', '31', '25 +0100']
# ['12/Dec/2015', '18', '31', '25 +0100']
# ['12/Dec/2015', '18', '32', '10 +0100']
# ['12/Dec/2015', '18', '32', '11 +0100']
# ['12/Dec/2015', '18', '32', '56 +0100']
# ['07/Aug/2016', '06', '13', '23 +0200']
# ['07/Aug/2016', '06', '13', '23 +0200']

# %%
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-73-0e0013a92289> in <module>
# ----> 1 sqlquery = spark.sql("SELECT count(data_detail) from logs where data_detail like '%404%' ").show()
#
# ~\Anaconda3\lib\site-packages\pyspark\sql\session.py in sql(self, sqlQuery)
#     647         [Row(f1=1, f2=u'row1'), Row(f1=2, f2=u'row2'), Row(f1=3, f2=u'row3')]
#     648         """
# --> 649         return DataFrame(self._jsparkSession.sql(sqlQuery), self._wrapped)
#     650
#     651     @since(2.0)
#
# ~\Anaconda3\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
# -> 1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#    1307         for temp_arg in temp_args:
#
# ...
