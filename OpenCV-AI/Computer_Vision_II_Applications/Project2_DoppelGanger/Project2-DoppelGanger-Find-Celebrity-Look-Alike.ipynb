# %% [markdown]
# # <font color="blue">Project 2: DoppelGanger Find your Celebrity Look-Alike </font>
# We have seen how face Recognition algorithms work. In short, they convert a face into a high dimensional vector and then learn a feature space in that high dimension. Once the algorithm learns a robust feature space, you can add more people to the same space and they will form a different cluster.
#
# ### <font color="green">Your Task</font>
# In this project, we will build a Fun Application - We will use the Face Embeddings to **find a doppelganger or look-alike to a given person.** Specifically, we will give you images of two persons and a celebrity dataset. Your task will be to find their celebrity look-alike. The first person is **Sofia Solares** who looks like the American Singer **Selena Gomez** and the second one is **Shashikant Pedwal** who looks like Indian Film Actor **Amitabh Bachchan**.
#
# Given below is the Expected Output.
#
# ### <font color="green">Expected Output</font>
#
# ![](https://www.learnopencv.com/wp-content/uploads/2020/05/doppelganger-output-selena.jpg)
#
# ![](https://www.learnopencv.com/wp-content/uploads/2020/05/doppelganger-output-amitabh.jpg)
#
#
# By now, you should be able to discern what the problem is, and how you are going to solve it. You simply need a dataset which has enough celebrity faces and use face embeddings to match the test image with the celebrity face embeddings. That's enough Hint!
#
# ## <font color="blue">The Dataset</font>
# There are many datasets which contain images of celebrities. Some of them are:
# * [CelebA Dataset](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html)
# * [VGGFace](https://www.robots.ox.ac.uk/~vgg/data/vgg_face/)
# * [VGGFace2](http://www.robots.ox.ac.uk/~vgg/data/vgg_face2/)
# * [MS-Celeb-1M](https://www.microsoft.com/en-us/research/project/ms-celeb-1m-challenge-recognizing-one-million-celebrities-real-world/)
# * [Celebrity-Together Dataset](https://www.robots.ox.ac.uk/~vgg/data/celebrity_together/)
#
# ### <font color="green">celeb_mini Dataset</font>
# Since most of the datasets are huge in size, we have curated a small dataset for this experiment.
#
# We will use a subset of the Query set of the Celebrity Together Dataset in this project. The query dataset has around 1100 celebs and is ~400MB in size.
#
# The subset we have created is using 5 images per celebrity and it has been saved in the **`../resource/asnlib/publicdata/celeb_mini`** folder. It is ~70MB in size. We have also provided a **`celeb_mapping.npy`** file which has the mapping of the code name to the actual name of the celebrity.
#
# The **`celeb_mini`** folder has the following structure:
#
# ```
# celeb_mini
# └───n00000001
# │   └──n00000001_00000263.JPEG
# │   └──n00000001_00000405.JPEG
# │      ...
# └───n00000003
# │   └──n00000003_00000386.JPEG
# │   └──n00000003_00000488.JPEG
# │       ...
# │
# ```
#
# **`celeb_mapping.npy`** contains a dictionary which contains the mapping between the folder names and the celebrity's actual name as show below:
# ```
# {'n00000001': 'A.J. Buckley',
#  'n00000002': 'A.R. Rahman',
#  'n00000003': 'Aamir Khan',
#  'n00000004': 'Aaron Staton',
#  'n00000005': 'Aaron Tveit',
#  'n00000006': 'Aaron Yoo',
#  'n00000007': 'Abbie Cornish',
#  .
#  .
#  .
# }
# ```
#
#
# ## <font color="blue">Marks Distribution </font>
# 1. **Implementation - 70 Marks**
# 1. **Video/Text Explanation - 30 marks**
#
# #### <font color="red">Note that you are free to use any other dataset if you have the resources of space and compute to handle the large datasets.</font>

# %%
import os,random,glob
import dlib
import cv2
import numpy as np
import matplotlib.pyplot as plt
import time
# %matplotlib inline

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (6.0,6.0)
matplotlib.rcParams['image.cmap'] = 'gray'
matplotlib.rcParams['image.interpolation'] = 'bilinear'

# %% [markdown]
# ## <font color="blue">Load the model for face landmarks and face recognition</font>

# %% [markdown]
# Initialize Dlib’s Face Detector, Facial Landmark Detector and Face Recognition neural network objects
#
# #### <font color="red">You are free to use other face recognition models as well. </font>

# %%
# Path to landmarks and face recognition model files
PREDICTOR_PATH = 'shape_predictor_68_face_landmarks.dat'
FACE_RECOGNITION_MODEL_PATH = 'dlib_face_recognition_resnet_model_v1.dat'

# Initialize face detector, facial landmarks detector 
# and face recognizer
faceDetector = dlib.get_frontal_face_detector()
shapePredictor = dlib.shape_predictor(PREDICTOR_PATH)
faceRecognizer = dlib.face_recognition_model_v1(FACE_RECOGNITION_MODEL_PATH)

# %% [markdown]
# ## <font color="blue">Explore Data </font>
# In this section, we provide sample code of how to load the images and use the label mapping for your reference. This should help you get started with handling images and finding the embeddings.

# %%
# Root folder of the dataset
faceDatasetFolder = 'celeb_mini'
# Label -> Name Mapping file
labelMap = np.load("celeb_mapping.npy", allow_pickle=True).item()

# %%
for key, value in labelMap.items():
    print('labelMap["{}"] = "{}";'.format(key,value))

# %%
labelMap
# Out:
# {'n00000001': 'A.J. Buckley',
#  'n00000002': 'A.R. Rahman',
#  'n00000003': 'Aamir Khan',
#  'n00000004': 'Aaron Staton',
#  'n00000005': 'Aaron Tveit',
#  'n00000006': 'Aaron Yoo',
#  'n00000007': 'Abbie Cornish',
#  'n00000008': 'Abel Ferrara',
#  'n00000009': 'A P J Abdul Kalam',
#  'n00000010': 'Abigail Breslin',
#  'n00000011': 'Abigail Klein',
#  'n00000012': 'Abigail Spencer',
#  'n00000013': 'Abraham Benrubi',
#  'n00000014': 'Adam Baldwin',
#  'n00000015': 'Adam Beach',
#  'n00000016': 'Adam Brody',
#  'n00000017': 'Adam Buxton',
#  'n00000018': 'Adam Copeland',
#  'n00000019': 'Adam Driver',
#  'n00000020': 'Adam G. Sevani',
#  'n00000021': 'Adam Garcia',
#  'n00000022': 'Adam Godley',
#  'n00000023': 'Adam Goldberg',
#  'n00000024': 'Adam Gregory',
#  'n00000025': 'Adam Hicks',
#  'n00000026': 'Adam Lambert',
#  'n00000027': 'Adam Levine',
#  'n00000028': 'Adam Rodriguez',
#  'n00000029': 'Adelaide Clemens',
#  'n00000030': 'Adelaide Kane',
#  'n00000031': 'Adina Porter',
#  'n00000032': 'Aditya Roy Kapoor',
#  'n00000033': 'Adrian Grenier',
#  'n00000034': 'Adrian Paul',
#  'n00000035': 'Adriana Barraza',
#  'n00000036': 'Adrianne Curry',
#  'n00000037': 'Adrianne Palicki',
#  'n00000038': 'Adrienne Barbeau',
#  'n00000039': 'Agyness Deyn',
#  'n00000040': 'Aida Turturro',
#  'n00000041': 'Aidan Gillen',
#  'n00000042': 'Aidan Turner',
#  'n00000043': 'Ana Ivanovic',
#  'n00000044': 'Ajay Devgn',
#  'n00000045': 'Akshay Kumar',
#  'n00000046': 'Alain Delon',
#  'n00000047': 'Alan Alda',
#  'n00000048': 'Alan Cumming',
#  'n00000049': 'Alan Dale',
#  'n00000050': 'Alan Ladd',
#  'n00000051': 'Alan Rickman',
#  'n00000052': 'Alan Tudyk',
#  'n00000053': 'Alba Rohrwacher',
#  'n00000054': 'Aldis Hodge',
#  'n00000055': 'Alessandra Torresani',
#  'n00000056': 'Alex Borstein',
#  'n00000057': 'Alex Kingston',
#  'n00000058': 'Alex Newell',
#  'n00000059': 'Alex Pettyfer',
#  'n00000060': 'Alex Trebek',
#  'n00000061': 'Alex Wolff',
#  'n00000062': 'Alexa Davalos',
#  'n00000063': 'Alexander Gould',
#  'n00000064': 'Alexander Koch',
#  'n00000065': 'Alexander Ludwig',
#  'n00000066': 'Alexander Siddig',
#  'n00000067': 'Alexandra Breckenridge',
#  'n00000068': 'Alexandra Chando',
#  'n00000069': 'Alexandra Daddario',
#  'n00000070': 'Alexandra Roach',
#  'n00000071': 'Alexandria Deberry',
#  'n00000072': 'Alexia Fast',
#  'n00000073': 'Alexie Gilmore',
#  'n00000074': 'Alexis Dziena',
#  'n00000075': 'Alexis Knapp',
#  'n00000076': 'Alexz Johnson',
#  'n00000077': 'Alfre Woodard',
#  'n00000078': 'Alfred Enoch',
#  'n00000079': 'Alfred Hitchcock',
#  'n00000080': 'Alfred Molina',
#  'n00000081': 'Ali Fedotowsky',
#  'n00000082': 'Ali Landry',
#  'n00000083': 'Alice Braga',
#  'n00000084': 'Alice Cooper',
#  'n00000085': 'Alice Englert',
#  'n00000086': 'Alice Eve',
#  'n00000087': 'Alice Greczyn',
#  'n00000088': 'Alicja Bachleda',
#  'n00000089': 'Alison Arngrim',
#  'n00000090': 'Alison Eastwood',
#  'n00000091': 'Alison Pill',
#  'n00000092': 'Alison Steadman',
#  'n00000093': 'Alison Sweeney',
#  'n00000094': 'Allie Gonino',
#  'n00000095': 'Allison Williams',
#  'n00000096': 'Amanda Detmer',
#  'n00000097': 'Amanda Seyfried',
#  'n00000098': 'Amandla Stenberg',
#  'n00000099': 'Amaury Nolasco',
#  'n00000100': 'Amber Riley',
#  'n00000101': 'America Ferrera',
#  'n00000102': 'Amitabh Bachchan',
#  'n00000103': 'Amy Davidson',
#  'n00000104': 'Amy Nuttall',
#  'n00000105': 'Amy Poehler',
#  'n00000106': 'Amy Schumer',
#  'n00000107': 'Ana Gasteyer',
#  'n00000108': 'Ana Mulvoy-Ten',
#  'n00000109': 'Anastasia Griffith',
#  'n00000110': 'Andre Braugher',
#  'n00000111': 'Andrea Bowen',
#  'n00000112': 'Andrea Riseborough',
#  'n00000113': 'Andrea Roth',
#  'n00000114': 'Andrew Buchan',
#  'n00000115': 'Andrew Dice Clay',
#  'n00000116': 'Andrew Garfield',
#  'n00000117': 'Andrew Keegan',
#  'n00000118': 'Andrew Lee Potts',
#  'n00000119': 'Andrew McCarthy',
#  'n00000120': 'Andrew Rannells',
#  'n00000121': 'Andrew Scott',
#  'n00000122': 'Andy Milonakis',
#  'n00000123': 'Andy Richter',
#  'n00000124': 'Andy Samberg',
#  'n00000125': 'Andy Whitfield',
#  'n00000126': 'Aneurin Barnard',
#  'n00000127': 'Ang Lee',
#  'n00000128': 'Angel Coulby',
#  'n00000129': 'Angela Kinsey',
#  'n00000130': 'Angell Conwell',
#  'n00000131': 'Anika Noni Rose',
#  'n00000132': 'Anil Kapoor',
#  'n00000133': 'Anita Briem',
#  'n00000134': 'Ann-Margret',
#  'n00000135': 'AnnaSophia Robb',
#  'n00000136': 'Anna Gunn',
#  'n00000137': 'Anna Maria Perez de Tagle',
#  'n00000138': 'Anna Wintour',
#  'n00000139': 'Annabeth Gish',
#  'n00000140': 'Annaleigh Ashford',
#  'n00000141': 'Anne Archer',
#  'n00000142': 'Anne Hathaway',
#  'n00000143': 'Annie Clark',
#  'n00000144': 'Ansel Elgort',
#  'n00000145': 'Anson Mount',
#  'n00000146': 'Anthony Anderson',
#  'n00000147': 'Anthony Head',
#  'n00000148': 'Anthony Mackie',
#  'n00000149': 'Andres Iniesta',
#  'n00000150': 'Anthony Rapp',
#  'n00000151': 'Anton Yelchin',
#  'n00000152': 'Antonia Campbell-Hughes',
#  'n00000153': 'Antonio Cupo',
#  'n00000154': 'Andrew Marr',
#  'n00000155': 'Aramis Knight',
#  'n00000156': 'Arden Cho',
#  'n00000157': 'Arden Myrin',
#  'n00000158': 'Arian Foster',
#  'n00000159': 'Ariana Richards',
#  'n00000160': 'Arielle Vandenberg',
#  'n00000161': 'Andy Murray',
#  'n00000162': 'Armand Assante',
#  'n00000163': 'Armie Hammer',
#  'n00000164': 'Arnold Vosloo',
#  'n00000165': 'Asa Butterfield',
#  'n00000166': 'Ashley Greene',
#  'n00000167': 'Ashley Hinshaw',
#  'n00000168': 'Ashley Jensen',
#  'n00000169': 'Ashley Jones',
#  'n00000170': 'Ashley Madekwe',
#  'n00000171': 'Ashley Rickards',
#  'n00000172': 'Ashton Holmes',
#  'n00000173': 'Atticus Shaffer',
#  'n00000174': 'Audra McDonald',
#  'n00000175': 'Audrey Hepburn',
#  'n00000176': 'Audrina Patridge',
#  'n00000177': 'Austin North',
#  'n00000178': 'Autumn Reeser',
#  'n00000179': 'Ava Allan',
#  'n00000180': 'Avan Jogia',
#  'n00000181': 'Azita Ghanizada',
#  'n00000182': 'Ariane Moffatt',
#  'n00000183': 'B.J. Novak',
#  'n00000184': 'Bahar Soomekh',
#  'n00000185': 'Bai Ling',
#  'n00000186': 'Bailey Chase',
#  'n00000187': 'Brett Lee',
#  'n00000188': 'Barbara Eden',
#  'n00000189': 'Barbara Hershey',
#  'n00000190': 'Barry Watson',
#  'n00000191': 'Bear Grylls',
#  'n00000192': 'Beatrice Rosen',
#  'n00000193': 'Beau Mirchoff',
#  'n00000194': 'Becca Tobin',
#  'n00000195': 'Becki Newton',
#  'n00000196': 'Bellamy Young',
#  'n00000197': 'Ben Chaplin',
#  'n00000198': 'Ben Daniels',
#  'n00000199': 'Ben Feldman',
#  'n00000200': 'Ben McKenzie',
#  'n00000201': 'Ben Miller',
#  'n00000202': 'Ben Stiller',
#  'n00000203': 'Ben Whishaw',
#  'n00000204': 'Benjamin Stockham',
#  'n00000205': 'Beth Grant',
#  'n00000206': 'Beth Ostrosky',
#  'n00000207': 'Bethany Mota',
#  'n00000208': 'Betsy Russell',
#  'n00000209': 'Betty White',
#  'n00000210': 'Beverley Mitchell',
#  'n00000211': 'Bianca Lawson',
#  'n00000212': 'Bill Duke',
#  'n00000213': 'Bill Nighy',
#  'n00000214': 'Bill Pullman',
#  'n00000215': 'Billie Joe Armstrong',
#  'n00000216': 'Billy Burke',
#  'n00000217': 'Billy Campbell',
#  'n00000218': 'Billy Connolly',
#  'n00000219': 'Billy Dee Williams',
#  'n00000220': 'Billy Miller',
#  'n00000221': 'Billy Unger',
#  'n00000222': 'Bingbing Fan',
#  'n00000223': 'Bingbing Li',
#  'n00000224': 'Daniel Lavoie',
#  'n00000225': 'Blair Underwood',
#  'n00000226': 'Blake Lively',
#  'n00000227': 'Blake Michael',
#  'n00000228': 'Blake Shelton',
#  'n00000229': 'Bob Barker',
#  'n00000230': 'Bobby Cannavale',
#  'n00000231': 'Bojana Novakovic',
#  'n00000232': 'Bonnie Bedelia',
#  'n00000233': 'Bonnie Somerville',
#  'n00000234': 'Bonnie Wright',
#  'n00000235': 'Booboo Stewart',
#  'n00000236': 'Boris Kodjoe',
#  'n00000237': 'Brad Paisley',
#  'n00000238': 'Bradley Cooper',
#  'n00000239': 'Bradley Steven Perry',
#  'n00000240': 'Brande Roderick',
#  'n00000241': 'Brandon T. Jackson',
#  'n00000242': 'Branka Katic',
#  'n00000243': 'Breckin Meyer',
#  'n00000244': 'Brenda Blethyn',
#  'n00000245': 'Brenda Song',
#  'n00000246': 'Brenda Vaccaro',
#  'n00000247': 'Brendan Gleeson',
#  'n00000248': 'Brendan Hines',
#  'n00000249': 'Bret McKenzie',
#  'n00000250': 'Brett Davern',
#  'n00000251': 'Brian Blessed',
#  'n00000252': 'Brian Cox',
#  'n00000253': 'Brian Dennehy',
#  'n00000254': 'Bridget Moynahan',
#  'n00000255': 'Bridget Regan',
#  'n00000256': 'Brigitte Nielsen',
#  'n00000257': 'Brit Marling',
#  'n00000258': 'Britne Oldford',
#  'n00000259': 'Brittany Curran',
#  'n00000260': 'Brooke Burke-Charvet',
#  'n00000261': 'Brooke Hogan',
#  'n00000262': 'Bruce Boxleitner',
#  'n00000263': 'Bruce McGill',
#  'n00000264': 'Bruno Ganz',
#  'n00000265': 'Bruno Mars',
#  'n00000266': 'David Wright',
#  'n00000267': 'Bryan Greenberg',
#  'n00000268': 'Burt Reynolds',
#  'n00000269': 'CCH Pounder',
#  'n00000270': 'Caitlin FitzGerald',
#  'n00000271': 'Caitriona Balfe',
#  'n00000272': 'Caity Lotz',
#  'n00000273': 'Callan McAuliffe',
#  'n00000274': 'Callie Thorne',
#  'n00000275': 'Cameron Boyce',
#  'n00000276': 'Cameron Bright',
#  'n00000277': 'Cameron Richardson',
#  'n00000278': 'Camilla Belle',
#  'n00000279': 'Camille Grammer',
#  'n00000280': 'Camille Guaty',
#  'n00000281': 'Camille Winbush',
#  'n00000282': 'Candace Cameron Bure',
#  'n00000283': 'Candice Accola',
#  'n00000284': 'Candice Patton',
#  'n00000285': 'Candice Swanepoel',
#  'n00000286': 'Candis Cayne',
#  'n00000287': 'Cara Delevingne',
#  'n00000288': 'Carey Mulligan',
#  'n00000289': 'Carla Gallo',
#  'n00000290': 'Carlos Ponce',
#  'n00000291': 'Carly Chaikin',
#  'n00000292': 'Carly Craig',
#  'n00000293': 'Carmine Giovinazzo',
#  'n00000294': 'Caroline Rhea',
#  'n00000295': 'Carolyn Hennesy',
#  'n00000296': 'Carolyn Jones',
#  'n00000297': 'Carrie Ann Inaba',
#  'n00000298': 'Carrie Brownstein',
#  'n00000299': 'Carrie Fisher',
#  'n00000300': 'Carrie Keagan',
#  'n00000301': 'Carrie Preston',
#  'n00000302': 'Carrie Underwood',
#  'n00000303': 'Carroll Baker',
#  'n00000304': 'Carter Jenkins',
#  'n00000305': 'Casey Affleck',
#  'n00000306': 'Casey Wilson',
#  'n00000307': 'Cassandra Peterson',
#  'n00000308': 'Cassandra Scerbo',
#  'n00000309': 'Cassi Thomson',
#  'n00000310': 'Catalina Sandino Moreno',
#  'n00000311': 'Caterina Murino',
#  'n00000312': 'Caterina Scorsone',
#  'n00000313': 'Catherine Hardwicke',
#  'n00000314': 'Cedric the Entertainer',
#  'n00000315': 'CeeLo Green',
#  'n00000316': 'Celeste Holm',
#  'n00000317': 'Celia Imrie',
#  'n00000318': 'Celia Weston',
#  'n00000319': 'Cerina Vincent',
#  'n00000320': 'Chace Crawford',
#  'n00000321': 'Chadwick Boseman',
#  'n00000322': 'Charice',
#  'n00000323': 'Charlene Amoia',
#  'n00000324': 'Charlene Tilton',
#  'n00000325': 'Charles Dance',
#  'n00000326': 'Charles Durning',
#  'n00000327': 'Charles Michael Davis',
#  'n00000328': 'Charles S. Dutton',
#  'n00000329': 'Charlie Bewley',
#  'n00000330': 'Charlie Day',
#  'n00000331': 'Charlotte Gainsbourg',
#  'n00000332': 'Charlotte Rae',
#  'n00000333': 'Charlotte Ross',
#  'n00000334': 'Charlotte Sullivan',
#  'n00000335': 'Charlyne Yi',
#  'n00000336': 'Charo',
#  'n00000337': 'Chase Masterson',
#  'n00000338': 'Chazz Palminteri',
#  'n00000339': 'Chelsea Handler',
#  'n00000340': 'Chelsea Hobbs',
#  'n00000341': 'Chelsea Kane',
#  'n00000342': 'Chelsea Peretti',
#  'n00000343': 'Cher',
#  'n00000344': 'Cheri Oteri',
#  'n00000345': 'Cherie Lunghi',
#  'n00000346': 'Cheryl Burke',
#  'n00000347': 'Cheryl Ladd',
#  'n00000348': 'Chi McBride',
#  'n00000349': 'Chiara Mastroianni',
#  'n00000350': 'Chin Han',
#  'n00000351': 'China Anne McClain',
#  'n00000352': 'China Chow',
#  'n00000353': 'Chiwetel Ejiofor',
#  'n00000354': 'Chloe Bennet',
#  'n00000355': 'Chloe Bridges',
#  'n00000356': 'Chloe Dykstra',
#  'n00000357': 'Chris Bauer',
#  'n00000358': 'Chris Brown',
#  'n00000359': 'Chris Carmack',
#  'n00000360': 'Chris Colfer',
#  'n00000361': 'Chris Hemsworth',
#  'n00000362': 'Chris Lowell',
#  'n00000363': 'Chris Marquette',
#  'n00000364': 'Chris Martin',
#  'n00000365': 'Chris Messina',
#  'n00000366': 'Chris Pine',
#  'n00000367': 'Chris Riggi',
#  'n00000368': 'Chris Young',
#  'n00000369': 'Chris Zylka',
#  'n00000370': 'Christa B. Allen',
#  'n00000371': 'Christian Kane',
#  'n00000372': 'Christian Serratos',
#  'n00000373': 'Christie Brinkley',
#  'n00000374': 'Christina Hendricks',
#  'n00000375': 'Christina Milian',
#  'n00000376': 'Christina Moore',
#  'n00000377': 'Christina Ricci',
#  'n00000378': 'Christine Baranski',
#  'n00000379': 'Christine Lahti',
#  'n00000380': 'Christine Lakin',
#  'n00000381': 'Christine Teigen',
#  'n00000382': 'Christopher Abbott',
#  'n00000383': 'Christopher Egan',
#  'n00000384': 'Christopher McDonald',
#  'n00000385': 'Christopher Mintz-Plasse',
#  'n00000386': 'Christy Carlson Romano',
#  'n00000387': 'Ciara Bravo',
#  'n00000388': 'Cicely Tyson',
#  'n00000389': 'Cierra Ramirez',
#  'n00000390': 'Cilla Black',
#  'n00000391': 'Cillian Murphy',
#  'n00000392': 'Cindy Williams',
#  'n00000393': 'Claire Coffee',
#  'n00000394': 'Claire Forlani',
#  'n00000395': 'Clara Bow',
#  'n00000396': 'Clara Lago',
#  'n00000397': 'Clark Duke',
#  'n00000398': 'Clark Gable',
#  'n00000399': 'Clark Gregg',
#  'n00000400': 'Claude Rains',
#  'n00000401': 'Claudia Black',
#  'n00000402': 'Claudia Lee',
#  'n00000403': 'Claudia Wells',
#  'n00000404': 'Clea DuVall',
#  'n00000405': 'Cliff Curtis',
#  'n00000406': 'Clive Owen',
#  'n00000407': 'Cody Linley',
#  'n00000408': 'Colin Donnell',
#  'n00000409': 'Colin Egglesfield',
#  'n00000410': 'Colin Ferguson',
#  'n00000411': 'Colin Firth',
#  'n00000412': 'Colin Hanks',
#  'n00000413': 'Colton Haynes',
#  'n00000414': 'Common',
#  'n00000415': 'Conchata Ferrell',
#  'n00000416': 'Connie Britton',
#  'n00000417': 'Connie Nielsen',
#  'n00000418': 'Connie Stevens',
#  'n00000419': 'Connor Trinneer',
#  'n00000420': 'Constance Zimmer',
#  'n00000421': 'Corbin Bleu',
#  'n00000422': 'Corey Sevier',
#  'n00000423': 'Corey Stoll',
#  'n00000424': 'Corin Nemec',
#  'n00000425': 'Cory Monteith',
#  'n00000426': 'Costas Mandylor',
#  'n00000427': 'Cote de Pablo',
#  'n00000428': 'Elon Musk',
#  'n00000429': 'Courtney Thorne-Smith',
#  'n00000430': 'Craig Bierko',
#  'n00000431': 'Craig Ferguson',
#  'n00000432': 'Craig Horner',
#  'n00000433': 'Craig Olejnik',
#  'n00000434': 'Craig Parker',
#  'n00000435': 'Craig Robinson',
#  'n00000436': 'Cristin Milioti',
#  'n00000437': 'Crystal Allen',
#  'n00000438': 'Crystal Bernard',
#  'n00000439': 'Crystal Reed',
#  'n00000440': 'Frank Lampard',
#  'n00000441': 'Cyndi Lauper',
#  'n00000442': 'Cynthia Daniel',
#  'n00000443': 'D.B. Sweeney',
#  'n00000444': 'D.B. Woodside',
#  'n00000445': 'Dakota Fanning',
#  'n00000446': 'Dale Dickey',
#  'n00000447': 'Damian Lewis',
#  'n00000448': 'Damon Lindelof',
#  'n00000449': 'Damon Wayans',
#  'n00000450': 'Dan Aykroyd',
#  'n00000451': 'Dan Fogler',
#  'n00000452': 'Dan Stevens',
#  'n00000453': 'Dana Delany',
#  'n00000454': 'Dane Cook',
#  'n00000455': 'Danica McKellar',
#  'n00000456': 'Daniel Auteuil',
#  'n00000457': 'Daniel Craig',
#  'n00000458': 'Daniel Dae Kim',
#  'n00000459': 'Daniel Feuerriegel',
#  'n00000460': 'Daniel Franzese',
#  'n00000461': 'Daniel Stern',
#  'n00000462': 'Frans Timmermans',
#  'n00000463': 'Daniel Tosh',
#  'n00000464': 'Daniela Ruah',
#  'n00000465': 'Daniella Monet',
#  'n00000466': 'Danielle Campbell',
#  'n00000467': 'Danielle Fishel',
#  'n00000468': 'Danielle Panabaker',
#  'n00000469': 'Danny Dyer',
#  'n00000470': 'Danny Masterson',
#  'n00000471': 'Danny McBride',
#  'n00000472': 'Danny Pino',
#  'n00000473': 'Danny Webb',
#  'n00000474': 'Daphne Zuniga',
#  'n00000475': 'Daren Kagasoff',
#  'n00000476': 'Darin Brooks',
#  'n00000477': 'Darren Criss',
#  'n00000478': 'Dave Annable',
#  'n00000479': 'Dave Bautista',
#  'n00000480': 'Dave Foley',
#  'n00000481': 'David Attenborough',
#  'n00000482': 'David Cassidy',
#  'n00000483': 'David Chokachi',
#  'n00000484': 'David Denman',
#  'n00000485': 'Gloria Macapagal-Arroyo',
#  'n00000486': 'David Eigenberg',
#  'n00000487': 'David Faustino',
#  'n00000488': 'David Giuntoli',
#  'n00000489': 'David Harewood',
#  'n00000490': 'David Hedison',
#  'n00000491': 'David Henrie',
#  'n00000492': 'David James Elliott',
#  'n00000493': 'David Jason',
#  'n00000494': 'David Koechner',
#  'n00000495': 'David Kross',
#  'n00000496': 'David Lambert',
#  'n00000497': 'David Letterman',
#  'n00000498': 'David Lyons',
#  'n00000499': 'David Mamet',
#  'n00000500': 'David Mazouz',
#  'n00000501': 'David Morrissey',
#  'n00000502': 'David Morse',
#  'n00000503': 'David Niven',
#  'n00000504': 'David Oyelowo',
#  'n00000505': 'David Schwimmer',
#  'n00000506': 'David Strathairn',
#  'n00000507': 'David Suchet',
#  'n00000508': 'David Sutcliffe',
#  'n00000509': 'David Tennant',
#  'n00000510': 'David Thewlis',
#  'n00000511': 'David Warner',
#  'n00000512': 'David Wenham',
#  'n00000513': 'David Zayas',
#  'n00000514': 'Dawn French',
#  'n00000515': 'Dawn Olivieri',
#  'n00000516': 'Dawn Wells',
#  'n00000517': 'Dawna Lee Heising',
#  'n00000518': 'DeForest Kelley',
#  'n00000519': 'Dean Cain',
#  'n00000520': 'Dean Geyer',
#  'n00000521': 'Dean Martin',
#  'n00000522': 'Debby Ryan',
#  'n00000523': 'Debi Mazar',
#  'n00000524': 'Deborah Kerr',
#  'n00000525': 'Debra Jo Rupp',
#  'n00000526': 'Debra Wilson',
#  'n00000527': 'Debra Winger',
#  'n00000528': 'Jack Ma',
#  'n00000529': 'Deidre Hall',
#  'n00000530': 'Della Reese',
#  'n00000531': 'Demian Bichir',
#  'n00000532': 'Denis Leary',
#  'n00000533': 'Denise Crosby',
#  'n00000534': 'Denise Richards',
#  'n00000535': 'Dennis Franz',
#  'n00000536': 'Dennis Haysbert',
#  'n00000537': 'Dennis Weaver',
#  'n00000538': 'Derek Hough',
#  'n00000539': 'Derek Jacobi',
#  'n00000540': 'Derek Mears',
#  'n00000541': 'Derek Theler',
#  'n00000542': 'Dermot Mulroney',
#  'n00000543': 'Desmond Harrington',
#  'n00000544': 'Devon Aoki',
#  'n00000545': 'Devon Bostick',
#  'n00000546': 'Devon Werkheiser',
#  'n00000547': 'Dexter Fletcher',
#  'n00000548': 'Diablo Cody',
#  'n00000549': 'Diana Rigg',
#  'n00000550': 'Diane Farr',
#  'n00000551': 'Diane Keaton',
#  'n00000552': 'Diane Kruger',
#  'n00000553': 'Dianne Wiest',
#  'n00000554': 'Dick Van Dyke',
#  'n00000555': 'Diedrich Bader',
#  'n00000556': 'Diego Klattenhoff',
#  'n00000557': 'Diego Luna',
#  'n00000558': 'Dina Manzo',
#  'n00000559': 'Dina Merrill',
#  'n00000560': 'Dina Meyer',
#  'n00000561': 'Diogo Morgado',
#  'n00000562': 'Diora Baird',
#  'n00000563': 'Dirk Benedict',
#  'n00000564': 'Dirk Bogarde',
#  'n00000565': 'James Anderson',
#  'n00000566': 'Domhnall Gleeson',
#  'n00000567': 'Dominic Cooper',
#  'n00000568': 'Dominic Keating',
#  'n00000569': 'Dominique Swain',
#  'n00000570': 'Don Rickles',
#  'n00000571': 'Donal Logue',
#  'n00000572': 'Donald Glover',
#  'n00000573': 'Donald Pleasence',
#  'n00000574': 'Donald Sutherland',
#  'n00000575': 'Donna Dixon',
#  'n00000576': 'Donna Douglas',
#  'n00000577': 'Donna Mills',
#  'n00000578': 'Donna Murphy',
#  'n00000579': 'Donna Reed',
#  'n00000580': 'Donnie Yen',
#  'n00000581': 'Doona Bae',
#  'n00000582': 'Dorothy Dandridge',
#  'n00000583': 'Dorothy Malone',
#  'n00000584': 'Dot-Marie Jones',
#  'n00000585': 'Douglas Booth',
#  'n00000586': 'Douglas Smith',
#  'n00000587': 'Dougray Scott',
#  'n00000588': 'Doutzen Kroes',
#  'n00000589': 'Dove Cameron',
#  'n00000590': 'Dr. Dre',
#  'n00000591': 'Drake Bell',
#  'n00000592': 'Drea de Matteo',
#  'n00000593': 'Dreama Walker',
#  'n00000594': 'Drew Carey',
#  'n00000595': 'Drew Fuller',
#  'n00000596': 'Drew Roy',
#  'n00000597': 'Drew Seeley',
#  'n00000598': 'Dustin Milligan',
#  'n00000599': 'Dwight Schultz',
#  'n00000600': 'Dwight Yoakam',
#  'n00000601': 'Dyan Cannon',
#  'n00000602': 'Dylan Baker',
#  'n00000603': 'Dylan Bruce',
#  'n00000604': 'Dylan Everett',
#  'n00000605': 'Dylan McDermott',
#  'n00000606': 'Dylan Minnette',
#  'n00000607': 'Dylan Moran',
#  'n00000608': 'Dylan Neal',
#  'n00000609': 'Dylan Sprayberry',
#  'n00000610': 'Eamonn Walker',
#  'n00000611': 'Eartha Kitt',
#  'n00000612': 'Ed Begley',
#  'n00000613': 'Ed Begley Jr.',
#  'n00000614': 'Ed Weeks',
#  'n00000615': 'Ed Westwick',
#  'n00000616': 'Eddie Albert',
#  'n00000617': 'Eddie Cahill',
#  'n00000618': 'Eddie Cibrian',
#  'n00000619': 'Eddie Griffin',
#  'n00000620': 'Eddie Izzard',
#  'n00000621': 'Eddie Kaye Thomas',
#  'n00000622': 'Eddie McClintock',
#  'n00000623': 'Eddie Vedder',
#  'n00000624': 'Edgar Wright',
#  'n00000625': 'Edie McClurg',
#  'n00000626': 'Eduardo Noriega',
#  'n00000627': 'Edward Asner',
#  'n00000628': 'Efren Ramirez',
#  'n00000629': 'Eileen Brennan',
#  'n00000630': 'Eileen Davidson',
#  'n00000631': 'Eion Bailey',
#  'n00000632': 'Elaine Cassidy',
#  'n00000633': 'Elaine Hendrix',
#  'n00000634': 'Eleanor Parker',
#  'n00000635': 'Eleanor Tomlinson',
#  'n00000636': 'Electra Avellan',
#  'n00000637': 'Eli Roth',
#  'n00000638': 'Eli Wallach',
#  'n00000639': 'Elias Koteas',
#  'n00000640': 'Elisa Donovan',
#  'n00000641': 'Elisabeth Moss',
#  'n00000642': 'Elisabetta Canalis',
#  'n00000643': 'Elise Neal',
#  'n00000644': 'Elizabeth McGovern',
#  'n00000645': 'Elle Fanning',
#  'n00000646': 'Elle Macpherson',
#  'n00000647': 'Ellen Burstyn',
#  'n00000648': 'Ellen Wong',
#  'n00000649': 'Elliott Gould',
#  'n00000650': 'Elodie Yung',
#  'n00000651': 'Elyes Gabel',
#  'n00000652': 'Embeth Davidtz',
#  'n00000653': 'Emile Hirsch',
#  'n00000654': 'Emily Atack',
#  'n00000655': 'Emily Bergl',
#  'n00000656': 'Emily Head',
#  'n00000657': 'Emily Watson',
#  'n00000658': 'Emir Kusturica',
#  'n00000659': 'Emma Bunton',
#  'n00000660': 'Emma Kenney',
#  'n00000661': 'Emma Rigby',
#  'n00000662': 'Emma Stone',
#  'n00000663': 'Emmanuelle Chriqui',
#  'n00000664': 'Emmanuelle Seigner',
#  'n00000665': 'Emraan Hashmi',
#  'n00000666': 'Enrico Colantoni',
#  'n00000667': 'Enrique Murciano',
#  'n00000668': 'Eoin Macken',
#  'n00000669': 'Eric Braeden',
#  'n00000670': 'Eric Dane',
#  'n00000671': 'Eric Lively',
#  'n00000672': 'Eric McCormack',
#  'n00000673': 'Eric Roberts',
#  'n00000674': 'Eric Schweig',
#  'n00000675': 'Eric Winter',
#  'n00000676': 'Erik Estrada',
#  'n00000677': 'Erik Per Sullivan',
#  'n00000678': 'Erin Andrews',
#  'n00000679': 'Erin Sanders',
#  'n00000680': 'Eriq La Salle',
#  'n00000681': 'Ernest Borgnine',
#  'n00000682': 'Ernie Hudson',
#  'n00000683': 'Errol Flynn',
#  'n00000684': 'Esai Morales',
#  'n00000685': 'Estelle Harris',
#  'n00000686': 'Esther Williams',
#  'n00000687': 'Eugene Levy',
#  'n00000688': 'Eugenio Derbez',
#  'n00000689': 'Jeff Bezos',
#  'n00000690': 'Eva Green',
#  'n00000691': 'Eva LaRue',
#  'n00000692': 'Eva Longoria',
#  'n00000693': 'Eva Marcille',
#  'n00000694': 'Evan Handler',
#  'n00000695': 'Evan Ross',
#  'n00000696': 'Evanna Lynch',
#  'n00000697': 'Ezra Miller',
#  'n00000698': 'Faith Hill',
#  'n00000699': 'Fanny Ardant',
#  'n00000700': 'Farah Zeynep Abdullah',
#  'n00000701': 'Farrah Abraham',
#  'n00000702': 'Farrah Fawcett',
#  'n00000703': 'Fawad Khan',
#  'n00000704': 'Felicia Day',
#  'n00000705': 'Felicity Jones',
#  'n00000706': 'Fergie',
#  'n00000707': 'Fernanda Romero',
#  'n00000708': 'Finola Hughes',
#  'n00000709': 'Fiona Gubelmann',
#  'n00000710': 'Fiona Shaw',
#  'n00000711': 'Fionnula Flanagan',
#  'n00000712': 'Florence Henderson',
#  'n00000713': 'Forest Whitaker',
#  'n00000714': 'Fran Kranz',
#  'n00000715': 'Frances McDormand',
#  'n00000716': 'Francesca Capaldi',
#  'n00000717': 'Francesca Eastwood',
#  'n00000718': 'Francesca Neri',
#  'n00000719': 'Francia Raisa',
#  'n00000720': 'Frank Vincent',
#  'n00000721': 'Fred Armisen',
#  'n00000722': 'Fred Astaire',
#  'n00000723': 'Fred Dryer',
#  'n00000724': 'Fred Willard',
#  'n00000725': 'Fred Williamson',
#  'n00000726': 'Freddie Highmore',
#  'n00000727': 'Freddie Mercury',
#  'n00000728': 'Freddie Prinze',
#  'n00000729': 'Freddie Stroma',
#  'n00000730': 'Freema Agyeman',
#  'n00000731': 'Freida Pinto',
#  'n00000732': 'G. Hannelius',
#  'n00000733': 'Gabe Kaplan',
#  'n00000734': 'Gabourey Sidibe',
#  'n00000735': 'Gabriel Byrne',
#  'n00000736': 'Gabriel Iglesias',
#  'n00000737': 'Gabriel Macht',
#  'n00000738': 'Gabrielle Carteris',
#  'n00000739': 'Gage Golightly',
#  'n00000740': 'Garcelle Beauvais',
#  'n00000741': 'Garrett Clayton',
#  'n00000742': 'Garrett Hedlund',
#  'n00000743': 'Garry Marshall',
#  'n00000744': 'Gary Busey',
#  'n00000745': 'Gary Cooper',
#  'n00000746': 'Gary Valentine',
#  'n00000747': 'Gaspard Ulliel',
#  'n00000748': 'Gates McFadden',
#  'n00000749': 'Gbenga Akinnagbe',
#  'n00000750': 'Geena Davis',
#  'n00000751': 'Gemma Arterton',
#  'n00000752': 'Gemma Atkinson',
#  'n00000753': 'Gemma Chan',
#  'n00000754': 'Gena Rowlands',
#  'n00000755': 'Gene Kelly',
#  'n00000756': 'Gene Tierney',
#  'n00000757': 'Gene Wilder',
#  'n00000758': 'Geno Segers',
#  'n00000759': 'George Sampson',
#  'n00000760': 'Georgia King',
#  'n00000761': 'Georgie Henley',
#  'n00000762': 'Georgina Chapman',
#  'n00000763': 'Gerald McRaney',
#  'n00000764': 'Geri Halliwell',
#  'n00000765': 'Gia Coppola',
#  'n00000766': 'Gia Mantegna',
#  'n00000767': 'Giancarlo Giannini',
#  'n00000768': 'Gigi Edgley',
#  'n00000769': 'Gil Bellows',
#  'n00000770': 'Gilles Marini',
#  'n00000771': 'Gillian Jacobs',
#  'n00000772': 'Gina Carano',
#  'n00000773': 'Gina McKee',
#  'n00000774': 'Ginger Rogers',
#  'n00000775': 'Ginnifer Goodwin',
#  'n00000776': 'Giovanni Ribisi',
#  'n00000777': 'Giuliana Rancic',
#  'n00000778': 'Giuseppe Tornatore',
#  'n00000779': 'Glen Hansard',
#  'n00000780': 'Glenn Close',
#  'n00000781': 'Gloria Grahame',
#  'n00000782': 'Gloria Reuben',
#  'n00000783': 'Gloria Steinem',
#  'n00000784': 'Gloria Swanson',
#  'n00000785': 'Golshifteh Farahani',
#  'n00000786': 'Goran Visnjic',
#  'n00000787': 'Gordon Ramsay',
#  'n00000788': 'Grace Lee Whitney',
#  'n00000789': 'Grace Park',
#  'n00000790': 'Grace Zabriskie',
#  'n00000791': 'Gracie Dzienny',
#  'n00000792': 'Grant Bowler',
#  'n00000793': 'Greer Garson',
#  'n00000794': 'Greer Grammer',
#  'n00000795': 'Greg Finley',
#  'n00000796': 'Greg Germann',
#  'n00000797': 'Greg Grunberg',
#  'n00000798': 'Greg Vaughan',
#  'n00000799': 'Gregg Sulkin',
#  'n00000800': 'Gregory Itzin',
#  'n00000801': 'Gregory Smith',
#  'n00000802': 'Greta Gerwig',
#  'n00000803': 'Grey Damon',
#  'n00000804': 'Gugu Mbatha-Raw',
#  'n00000805': 'Guillaume Canet',
#  'n00000806': 'Guy Pearce',
#  'n00000807': 'Gwendoline Christie',
#  'n00000808': 'Hailee Steinfeld',
#  'n00000809': 'Hal Sparks',
#  'n00000810': 'Haley Pullos',
#  'n00000811': 'Halston Sage',
#  'n00000812': 'Hamish Linklater',
#  'n00000813': 'Hana Mae Lee',
#  'n00000814': 'Hannah Marks',
#  'n00000815': 'Hannah Murray',
#  'n00000816': 'Hannah Simone',
#  'n00000817': 'Hannah Spearritt',
#  'n00000818': 'Hannah Storm',
#  'n00000819': 'Hans Zimmer',
#  'n00000820': 'Harry Connick Jr.',
#  'n00000821': 'Harry Hamlin',
#  'n00000822': 'Harry Shum Jr.',
#  'n00000823': 'Harry Styles',
#  'n00000824': 'Harry Treadaway',
#  'n00000825': 'Harvey Keitel',
#  'n00000826': 'Hattie Morahan',
#  'n00000827': 'Hayley Marie Norman',
#  'n00000828': 'Heather Graham',
#  'n00000829': 'Heather Hemmens',
#  'n00000830': 'Heather Matarazzo',
#  'n00000831': 'Heather Morris',
#  'n00000832': 'Heather Tom',
#  'n00000833': 'Hector Elizondo',
#  'n00000834': 'Hedy Lamarr',
#  'n00000835': 'Heidi Montag',
#  'n00000836': 'Heike Makatsch',
#  'n00000837': 'Helen George',
#  'n00000838': 'Helen Hunt',
#  'n00000839': 'Helen McCrory',
#  'n00000840': 'Helen Mirren',
#  'n00000841': 'Helen Slater',
#  'n00000842': 'Helena Bonham Carter',
#  'n00000843': 'Helena Christensen',
#  'n00000844': 'Helena Mattsson',
#  'n00000845': 'Henry Cavill',
#  'n00000846': 'Henry Fonda',
#  'n00000847': 'Henry Simmons',
#  'n00000848': 'Hilarie Burton',
#  'n00000849': 'Hilary Swank',
#  'n00000850': 'Hill Harper',
#  'n00000851': 'Hiroyuki Sanada',
#  'n00000852': 'Holland Taylor',
#  'n00000853': 'Holliday Grainger',
#  'n00000854': 'Holly Marie Combs',
#  'n00000855': 'Hope Davis',
#  'n00000856': 'Hope Solo',
#  'n00000857': 'Howard Keel',
#  'n00000858': 'Howie Mandel',
#  'n00000859': 'Hugh Bonneville',
#  'n00000860': 'Hugh Dancy',
#  'n00000861': 'Hugh Jackman',
#  'n00000862': 'Hugh Laurie',
#  'n00000863': 'Humphrey Bogart',
#  'n00000864': 'Hunter King',
#  'n00000865': 'Hunter Parrish',
#  'n00000866': 'Hutch Dano',
#  'n00000867': 'Hye-kyo Song',
#  'n00000868': 'Iain Glen',
#  'n00000869': 'Ian Somerhalder',
#  'n00000870': 'Ida Lupino',
#  'n00000871': 'Idina Menzel',
#  'n00000872': 'Idris Elba',
#  'n00000873': 'Illeana Douglas',
#  'n00000874': 'Imelda Staunton',
#  'n00000875': 'Inbar Lavi',
#  'n00000876': 'India Eisley',
#  'n00000877': 'India de Beaufort',
#  'n00000878': 'Indira Varma',
#  'n00000879': 'Ingrid Bergman',
#  'n00000880': 'Irina Shayk',
#  'n00000881': 'Irrfan Khan',
#  'n00000882': 'Isabel Lucas',
#  'n00000883': 'Isla Fisher',
#  'n00000884': 'Italia Ricci',
#  'n00000885': 'Ivan Sergei',
#  'n00000886': 'Ivana Baquero',
#  'n00000887': 'Iwan Rheon',
#  'n00000888': 'Izabella Miko',
#  'n00000889': 'Izabella Scorupco',
#  'n00000890': 'J.J. Abrams',
#  'n00000891': 'Jo Wilfried Tsonga',
#  'n00000892': 'J.K. Simmons',
#  'n00000893': 'JJ Feild',
#  'n00000894': 'Jacinda Barrett',
#  'n00000895': 'Jack Black',
#  'n00000896': 'Jack Coleman',
#  'n00000897': 'Jack Davenport',
#  'n00000898': 'Jack Griffo',
#  'n00000899': 'Jack Lemmon',
#  'n00000900': 'Jack Noseworthy',
#  'n00000901': 'Jack Reynor',
#  'n00000902': 'Jack Whitehall',
#  'n00000903': 'Jacki Weaver',
#  'n00000904': 'Jackie Cruz',
#  'n00000905': 'Jackie Sandler',
#  'n00000906': 'Jackson Brundage',
#  'n00000907': 'Jacob Artist',
#  'n00000908': 'Jacob Latimore',
#  'n00000909': 'Jacob Vargas',
#  'n00000910': 'Jacqueline Emerson',
#  'n00000911': 'Jacqueline Fernandez',
#  'n00000912': 'Jacqueline MacInnes Wood',
#  'n00000913': 'Jade Ramsey',
#  'n00000914': 'Jaden Smith',
#  'n00000915': 'Jai Courtney',
#  'n00000916': 'Kamal Hassan',
#  'n00000917': 'Jaime Winstone',
#  'n00000918': 'Jake Abel',
#  'n00000919': 'Jake Cherry',
#  'n00000920': 'Jake Johnson',
#  'n00000921': 'Jake McDorman',
#  'n00000922': 'Jake Short',
#  'n00000923': 'Jake T. Austin',
#  'n00000924': 'Jamel Debbouze',
#  'n00000925': 'James Badge Dale',
#  'n00000926': 'James Belushi',
#  'n00000927': 'James Corden',
#  'n00000928': 'James Cosmo',
#  'n00000929': 'James Cromwell',
#  'n00000930': 'James Dean',
#  'n00000931': 'James Denton',
#  'n00000932': 'James Earl Jones',
#  'n00000933': 'James Frain',
#  'n00000934': 'James Lafferty',
#  'n00000935': 'James Lipton',
#  'n00000936': 'James Marsden',
#  'n00000937': 'James Maslow',
#  'n00000938': 'James Mason',
#  'n00000939': 'James Nesbitt',
#  'n00000940': 'James Patrick Stuart',
#  'n00000941': 'James Purefoy',
#  'n00000942': 'James Rebhorn',
#  'n00000943': 'James Roday',
#  'n00000944': 'James Stewart',
#  'n00000945': 'James Woods',
#  'n00000946': 'Jami Gertz',
#  'n00000947': 'Jamie-Lynn Sigler',
#  'n00000948': 'Jamie Brewer',
#  'n00000949': 'Jamie Chung',
#  'n00000950': 'Jamie Foxx',
#  'n00000951': 'Jamie Gray Hyder',
#  'n00000952': 'Jana Kramer',
#  'n00000953': 'Jana Pallaske',
#  'n00000954': 'Jane Badler',
#  'n00000955': 'Jane Campion',
#  'n00000956': 'Jane Goldman',
#  'n00000957': 'Jane Horrocks',
#  'n00000958': 'Jane Levy',
#  'n00000959': 'Jane Lynch',
#  'n00000960': 'Jane Seymour',
#  'n00000961': 'Jane Wyman',
#  'n00000962': 'Janeane Garofalo',
#  'n00000963': 'Janel Moloney',
#  'n00000964': 'Janel Parrish',
#  'n00000965': 'Janet Jackson',
#  'n00000966': 'Janet McTeer',
#  'n00000967': 'Janet Montgomery',
#  'n00000968': 'Janice Dickinson',
#  'n00000969': 'Janina Gavankar',
#  'n00000970': 'Janine Turner',
#  'n00000971': 'January Jones',
#  'n00000972': 'Jared Gilmore',
#  'n00000973': 'Jared Harris',
#  'n00000974': 'Jared Leto',
#  'n00000975': 'Jasika Nicole',
#  'n00000976': 'Jasmine Guy',
#  'n00000977': 'Jasmine Waltz',
#  'n00000978': 'Jason Bateman',
#  'n00000979': 'Jason Behr',
#  'n00000980': 'Jason Clarke',
#  'n00000981': 'Jason David Frank',
#  'n00000982': 'Jason Dohring',
#  'n00000983': 'Jason Dolley',
#  'n00000984': 'Jason Earles',
#  'n00000985': 'Jason Gedrick',
#  'n00000986': 'Jason George',
#  'n00000987': 'Jason Lewis',
#  'n00000988': 'Jason Mantzoukas',
#  'n00000989': 'Jason Momoa',
#  'n00000990': 'Jason Segel',
#  'n00000991': 'Jay Baruchel',
#  'n00000992': 'Jayma Mays',
#  'n00000993': 'Jayne Atkinson',
#  'n00000994': 'Jayne Mansfield',
#  'n00000995': 'Jayne Wisener',
#  'n00000996': 'Jean-Marc Barr',
#  'n00000997': 'Jean-Paul Belmondo',
#  'n00000998': 'Jean Arthur',
#  'n00000999': 'Jean Harlow',
#  'n00001000': 'Jean Louisa Kelly',
#  ...}

# %%
# Each subfolder has images of a particular celeb
subfolders = os.listdir(faceDatasetFolder)

# Let us choose a random folder and display all images
random_folder = random.choice(subfolders)

# Also find out the name of the celeb from the folder name and folder-> name mapping dictionary loaded earlier
celebname = labelMap[random_folder]

# Load all images in the subfolder
imagefiles = os.listdir(os.path.join(faceDatasetFolder, random_folder))

# Read each image and display along with the filename and celeb name
for file in imagefiles:
#     Get full path of each image file
    fullPath = os.path.join(faceDatasetFolder,random_folder,file)
    im = cv2.imread(fullPath)
    plt.imshow(im[:,:,::-1])
    plt.show()
#     Also print the filename and celeb name
    print("File path = {}".format(fullPath))
    print("Celeb Name: {}".format(celebname))
# Out:
# File path = celeb_mini\n00000840\n00000840_00000046.JPEG
# Celeb Name: Helen Mirren
# File path = celeb_mini\n00000840\n00000840_00000115.JPEG
# Celeb Name: Helen Mirren
# File path = celeb_mini\n00000840\n00000840_00000271.JPEG
# Celeb Name: Helen Mirren
# File path = celeb_mini\n00000840\n00000840_00000355.JPEG
# Celeb Name: Helen Mirren
# File path = celeb_mini\n00000840\n00000840_00000512.JPEG
# Celeb Name: Helen Mirren

# %% [markdown]
# ## <font color="blue">TODO</font>
# You have to write the code for enrollment and testing to get the desired output as shown in the intro section.
#
# **You can take help from the code we had provided in week 4 material.**

# %% [markdown]
# ## <font color="red">1. Enrollment of Celeb Images </font>
# Process images one by and one.
#
# Convert image from RGB to BGR, because Dlib uses RGB as default format.
#
# Detect faces in the image and compute a face descriptor for each image and save them in an array so that it can be used during testing.

# %%
import re
subfolders = []
for x in os.listdir(faceDatasetFolder):
    xpath = os.path.join(faceDatasetFolder, x)
    if os.path.isdir(xpath):
        subfolders.append(xpath)

imagePaths = []
for i, subfolder in enumerate(subfolders):
    for x in os.listdir(subfolder):
        xpath = os.path.join(subfolder, x)
    if x.endswith('.JPEG'):
        imagePaths.append(xpath)
index = {}
i = 0
faceDescriptors = None
for imagePath in imagePaths:
        img = cv2.imread(imagePath)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        faces = faceDetector(img)
        for k, face in enumerate(faces):
                landmark_obj = shapePredictor(img,face)
                landmarks = []
                for f in landmark_obj.parts():
                    (x, y) = f.x, f.y
                    landmarks.append((x,y))
                faceDescriptor = faceRecognizer.compute_face_descriptor(img, landmark_obj)
                faceDescriptorList = [x for x in faceDescriptor]
                faceDescriptorNdarray = np.asarray(faceDescriptorList, dtype=np.float64)
                faceDescriptorNdarray = faceDescriptorNdarray[np.newaxis, :]
                if faceDescriptors is None:
                    faceDescriptors = faceDescriptorNdarray
                else:
                    faceDescriptors = np.concatenate((faceDescriptors, faceDescriptorNdarray), axis=0)
                folder_name = re.search("\\\\n(.+)\\\\",imagePath)
                folder = folder_name.group().split("\\",1)
                index_file = folder[1].split("\\",1)
                index[i] = labelMap[index_file[0]]
                i += 1

# %% [markdown]
# ## <font color="red">2. Testing</font>
# Once you have enrolled the celebs, you should be able to use them to find the closest celeb to the given test image using minimum distance rule.
#
# You need to find the embeddings of the test images and compare it with the enrolled celebs to find the look-alike.
#
# Finally, display the celeb along side the input image. Partial code is given.

# %%
faceDescriptors.shape
# Out:
# (1106, 128)

# %%
matplotlib.rcParams['figure.figsize'] = (12.0,12.0)

# %%
# read image
testImages = glob.glob('../resource/asnlib/publicdata/test-images/*.jpg')

for test in testImages:
    im = cv2.imread(test)
    imDlib = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
    
    #####################
    #  YOUR CODE HERE
    
    celeb_name = ""
    ####################
    
    plt.subplot(121)
    plt.imshow(imDlib)
    plt.title("test img")
    
    #TODO - display celeb image which looks like the test image instead of the black image. 
    plt.subplot(122)
    plt.imshow(np.zeros((200,200,3)))
    plt.title("Celeb Look-Alike={}".format(celeb_name))
    plt.show()
